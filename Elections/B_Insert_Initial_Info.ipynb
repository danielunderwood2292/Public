# %% [markdown]
# This Python Jupyter Notebook creates the intial information for use within the UK General Elections model

# %%
#Import required packages
import pyodbc
import sqlalchemy
from sqlalchemy import create_engine
import urllib
import pandas as pd

# %%
#Connect to database 'UK_General_Election' using SQlAlchemy
connection_str = "DRIVER={SQL SERVER};SERVER=DANZPOOTA;DATABASE=UK_General_Election;TRUSTED_CONNECTION=YES"
params = urllib.parse.quote_plus(connection_str)
engine = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)
conn = engine.connect()

# %%
#SQL statement to delete any data that might already exist in the tables
#This is the only initial information required so anything that currnetly exists is not needed
DeleteTableData = """
DELETE ElectionPredictionPollsUsed
DELETE ElectionPredictionCandidates
DELETE ElectionPredictionConstituencies
DELETE ElectionPredictionOverall
DELETE ElectionPredictionMeta

DELETE PollAnalysisConstituencies
DELETE PollAnalysisRegions
DELETE PollAnalysisMeta

DELETE PollDetails
DELETE PollMeta

DELETE Candidates
DELETE RegionConstituencies
DELETE Constituencies
DELETE Pollsters
DELETE Parties
DELETE RegionRegionTypes
DELETE Regions
DELETE RegionTypes"""

# %%
engine.execute(DeleteTableData)

# %%
#Location of file to be used
filename = "C:\\Users\\danmu\\Documents\\Elections\\2024_Python\\Initial_Data.xlsx"

# %%
regiontypes_df = pd.read_excel(filename, sheet_name='RegionTypes')
regiontypes_df.head()
# Out:
#        RegionType  RegionTypeRank
# 0    Constituency               2
# 1              GB               8
# 2  GBFiveLonSouth               6
# 3  GBFiveMidWales               6
# 4           GBSix               6

# %%
#Insert into database then read back out into a dataframe to check it has been inserted
regiontypes_df.to_sql('RegionTypes', conn, if_exists='append', index=False)
db_regiontypes_df = pd.read_sql('SELECT * From RegionTypes',conn)
db_regiontypes_df.head()
# Out:
#        RegionType  RegionTypeRank
# 0    Constituency               2
# 1              GB               8
# 2  GBFiveLonSouth               6
# 3  GBFiveMidWales               6
# 4           GBSix               6

# %%
regions_df = pd.read_excel(filename, sheet_name='Regions')
regions_df.head()
# Out:
#                         RegionName
# 0  Cardiff and South Central Wales
# 1                   Central London
# 2                 Central Scotland
# 3                     East England
# 4                      East London

# %%
regions_df.to_sql('Regions', conn, if_exists='append', index=False)
db_regions_df = pd.read_sql('SELECT * From Regions',conn)
db_regions_df.head()
# Out:
#                         RegionName
# 0  Cardiff and South Central Wales
# 1                   Central London
# 2                 Central Scotland
# 3                     East England
# 4                      East London

# %%
regionregiontypes_df = pd.read_excel(filename, sheet_name='RegionRegionTypes')
regionregiontypes_df.head()
# Out:
#        RegionType     RegionName
# 0              GB             GB
# 1  GBFiveLonSouth       Midlands
# 2  GBFiveLonSouth  North England
# 3  GBFiveLonSouth       Scotland
# 4  GBFiveLonSouth   South+London

# %%
regionregiontypes_df.to_sql('RegionRegionTypes', conn, if_exists='append', index=False)
db_regionregiontypes_df = pd.read_sql('SELECT * From RegionRegionTypes',conn)
db_regionregiontypes_df.head()
# Out:
#                 RegionXTypesID     RegionName      RegionType
# 0       GBFiveLonSouthMidlands       Midlands  GBFiveLonSouth
# 1  GBFiveLonSouthNorth England  North England  GBFiveLonSouth
# 2       GBFiveLonSouthScotland       Scotland  GBFiveLonSouth
# 3   GBFiveLonSouthSouth+London   South+London  GBFiveLonSouth
# 4          GBFiveLonSouthWales          Wales  GBFiveLonSouth

# %%
parties_df = pd.read_excel(filename, sheet_name='Parties')
parties_df.head()
# Out:
#   PartyAbbreviation              PartyFullName
# 0              APNI                   Alliance
# 1               Con               Conservative
# 2               DUP  Democratic Unionist Party
# 3             Green                      Green
# 4               Lab                     Labour

# %%
parties_df.to_sql('Parties', conn, if_exists='append', index=False)
db_parties_df = pd.read_sql('SELECT * From Parties',conn)
db_parties_df.head()
# Out:
#   PartyAbbreviation              PartyFullName
# 0              APNI                   Alliance
# 1               Con               Conservative
# 2               DUP  Democratic Unionist Party
# 3             Green                      Green
# 4               Lab                     Labour

# %%
pollsters_df = pd.read_excel(filename, sheet_name='Pollsters')
pollsters_df.head()
# Out:
#   PollsterName DefaultRegionType
# 0          BMG   ITL1Region-NINA
# 1    Deltapoll             GBSix
# 2   FindOutNow   ITL1Region-NINA
# 3    Focaldata                GB
# 4          ICM    GBFiveLonSouth

# %%
pollsters_df.to_sql('Pollsters', conn, if_exists='append', index=False)
db_pollsters_df = pd.read_sql('SELECT * From Pollsters',conn)
db_pollsters_df.head()
# Out:
#          PollsterName DefaultRegionType
# 0                 BMG   ITL1Region-NINA
# 1           Deltapoll             GBSix
# 2  Electoral Calculus            MRP632
# 3          FindOutNow   ITL1Region-NINA
# 4           Focaldata                GB

# %%
constituencies_df = pd.read_excel(filename, sheet_name='Constituencies')
constituencies_df.head()
# Out:
#        ONSID  PANO                    ConstituencyName  \
# 0  W07000081     1                    Aberafan Maesteg
# 1  S14000060     2                      Aberdeen North
# 2  S14000061     3                      Aberdeen South
# 3  S14000062     4  Aberdeenshire North and Moray East
# 4  S14000058     5   West Aberdeenshire and Kincardine
#
#               ClosestOldConstituency                            PAName  \
# 0                           Aberavon                  Aberafan Maesteg
# 1                     Aberdeen North                    Aberdeen North
# 2                     Aberdeen South                    Aberdeen South
# 3                   Banff and Buchan  Aberdeenshire North & Moray East
# 4  West Aberdeenshire and Kincardine   Aberdeenshire West & Kincardine
#
#   ConstituencyType    Nation ITL1Region  Electorate  TotalVotes  \
# 0           County     Wales      Wales       69817       44423
# 1          Borough  Scotland   Scotland       76895       50127
# 2          Borough  Scotland   Scotland       76560       50118
# 3           County  Scotland   Scotland       71485       45891
# 4           County  Scotland   Scotland       73634       53345
#
#    MajorityVotes  MajorityShare FirstParty SecondParty
# 0          13457       0.302929        Lab         Con
# 1          14210       0.283480        SNP         Con
# 2           5463       0.109003        SNP         Con
# 3           2399       0.052276        Con         SNP
# 4            843       0.015803        Con         SNP

# %%
constituencies_df.to_sql('Constituencies', conn, if_exists='append', index=False)
db_constituencies_df = pd.read_sql('SELECT * From Constituencies',conn)
db_constituencies_df.head()
# Out:
#        ONSID  PANO                    ConstituencyName ClosestOldConstituency  \
# 0  W07000081     1                    Aberafan Maesteg               Aberavon
# 1  S14000060     2                      Aberdeen North         Aberdeen North
# 2  S14000061     3                      Aberdeen South         Aberdeen South
# 3  S14000062     4  Aberdeenshire North and Moray East       Banff and Buchan
# 4  S14000063     6                  Airdrie and Shotts     Airdrie and Shotts
#
#                              PAName    Nation ConstituencyType ITL1Region  \
# 0                  Aberafan Maesteg     Wales           County      Wales
# 1                    Aberdeen North  Scotland          Borough   Scotland
# 2                    Aberdeen South  Scotland          Borough   Scotland
# 3  Aberdeenshire North & Moray East  Scotland           County   Scotland
# 4                  Airdrie & Shotts  Scotland           County   Scotland
#
#   FirstParty SecondParty  Electorate  TotalVotes  MajorityVotes  MajorityShare
# 0        Lab         Con       69817       44423          13457       0.302929
# 1        SNP         Con       76895       50127          14210       0.283480
# 2        SNP         Con       76560       50118           5463       0.109003
# 3        Con         SNP       71485       45891           2399       0.052276
# 4        SNP         Lab       70420       46338           5324       0.114895

# %%
RegionConstituencies_df = pd.read_excel(filename, sheet_name='RegionConstituencies')
RegionConstituencies_df.head()
# Out:
#          RegionName  ConstituencyName
# 0                GB  Aberafan Maesteg
# 1    Midlands+Wales  Aberafan Maesteg
# 2  South West Wales  Aberafan Maesteg
# 3                UK  Aberafan Maesteg
# 4             Wales  Aberafan Maesteg

# %%
RegionConstituencies_df.to_sql('RegionConstituencies', conn, if_exists='append', index=False)
db_RegionConstituencies_df = pd.read_sql('SELECT * From RegionConstituencies',conn)
db_RegionConstituencies_df.head()
# Out:
#                                         RegionConsID  \
# 0        Cardiff and South Central WalesCardiff East
# 1       Cardiff and South Central WalesCardiff North
# 2  Cardiff and South Central WalesCardiff South a...
# 3        Cardiff and South Central WalesCardiff West
# 4  Cardiff and South Central WalesMerthyr Tydfil ...
#
#               ConstituencyName                       RegionName
# 0                 Cardiff East  Cardiff and South Central Wales
# 1                Cardiff North  Cardiff and South Central Wales
# 2    Cardiff South and Penarth  Cardiff and South Central Wales
# 3                 Cardiff West  Cardiff and South Central Wales
# 4  Merthyr Tydfil and Aberdare  Cardiff and South Central Wales

# %%
Candidates_df = pd.read_excel(filename, sheet_name='Candidates')
Candidates_df.head()
# Out:
#        Constituency   Party  PreviousVotes  PreviousShare  \
# 0  Aberafan Maesteg     Lab          23509       0.529208
# 1  Aberafan Maesteg     Con          10052       0.226279
# 2  Aberafan Maesteg      PC           3991       0.089841
# 3  Aberafan Maesteg  Reform           3794       0.085406
# 4  Aberafan Maesteg      LD           1645       0.037030
#
#                 FullName    FirstName    Surname  Gender  SittingMP  FormerMP  \
# 0        Stephen Kinnock      Stephen    Kinnock     NaN          1       NaN
# 1         Abigail Mainon      Abigail     Mainon     NaN          0       NaN
# 2       Colin John Deere   Colin John      Deere     NaN          0       NaN
# 3         Mark Griffiths         Mark  Griffiths     NaN          0       NaN
# 4  Justin Mark Griffiths  Justin Mark  Griffiths     NaN          0       NaN
#
#    PreviousStanding  CurrentStanding
# 0                 1                1
# 1                 1                1
# 2                 1                1
# 3                 1                1
# 4                 1                1

# %%
Candidates_df.to_sql('Candidates', conn, if_exists='append', index=False)
db_Candidates_df = pd.read_sql('SELECT * From Candidates',conn)
db_Candidates_df.head()
# Out:
#              CandidateID      Constituency  Party  SittingMP FormerMP  \
# 0    Aberafan MaestegCon  Aberafan Maesteg    Con      False     None
# 1  Aberafan MaestegGreen  Aberafan Maesteg  Green      False     None
# 2    Aberafan MaestegLab  Aberafan Maesteg    Lab       True     None
# 3     Aberafan MaestegLD  Aberafan Maesteg     LD      False     None
# 4  Aberafan MaestegOther  Aberafan Maesteg  Other      False     None
#
#                 FullName    FirstName    Surname Gender  PreviousVotes  \
# 0         Abigail Mainon      Abigail     Mainon   None          10052
# 1             Nigel Hill        Nigel       Hill   None            701
# 2        Stephen Kinnock      Stephen    Kinnock   None          23509
# 3  Justin Mark Griffiths  Justin Mark  Griffiths   None           1645
# 4                   None         None       None   None            731
#
#    PreviousShare  PreviousStanding  CurrentStanding
# 0       0.226279                 1                1
# 1       0.015780                 1                1
# 2       0.529208                 1                1
# 3       0.037030                 1                1
# 4       0.016455                 1                1

# %%
conn.close()
