# %% [markdown]
# This Python Jupyter Notebook creates the intial information for use within the UK General Elections model

# %%
#Import required packages
import pyodbc
import sqlalchemy
from sqlalchemy import create_engine
import urllib
import pandas as pd

# %%
#Connect to database 'UK_General_Election' using SQlAlchemy
connection_str = "DRIVER={SQL SERVER};SERVER=DANZPOOTA;DATABASE=UK_General_Election;TRUSTED_CONNECTION=YES"
params = urllib.parse.quote_plus(connection_str)
engine = create_engine('mssql+pyodbc:///?odbc_connect=%s' % params)
conn = engine.connect()

# %%
#SQL statement to delete any data that might already exist in the tables
#This is the only initial information required so anything that currnetly exists is not needed
DeleteTableData = """DELETE Candidates
DELETE RegionConstituencies
DELETE Constituencies
DELETE Pollsters
DELETE Parties
DELETE RegionRegionTypes
DELETE Regions
DELETE RegionTypes"""

# %%
engine.execute(DeleteTableData)

# %%
#Location of file to be used
filename = "C:\\Users\\danmu\\Documents\\Elections\\2024_Python\\Initial_Data.xlsx"

# %%
regiontypes_df = pd.read_excel(filename, sheet_name='RegionTypes')
regiontypes_df.head()
# Out:
#      RegionType
# 0            UK
# 1            GB
# 2        Nation
# 3    ITL1Region
# 4  Constituency

# %%
#Insert into database then read back out into a dataframe to check it has been inserted
regiontypes_df.to_sql('RegionTypes', conn, if_exists='append', index=False)
db_regiontypes_df = pd.read_sql('SELECT * From RegionTypes',conn)
db_regiontypes_df.head()
# Out:
#      RegionType
# 0  Constituency
# 1            GB
# 2           ICM
# 3    ITL1Region
# 4        Nation

# %%
regions_df = pd.read_excel(filename, sheet_name='Regions')
regions_df.head()
# Out:
#                         RegionName
# 0  Cardiff and South Central Wales
# 1                 Central Scotland
# 2                     East England
# 3                    East Midlands
# 4                          England

# %%
regions_df.to_sql('Regions', conn, if_exists='append', index=False)
db_regions_df = pd.read_sql('SELECT * From Regions',conn)
db_regions_df.head()
# Out:
#                         RegionName
# 0  Cardiff and South Central Wales
# 1                 Central Scotland
# 2                     East England
# 3                    East Midlands
# 4                          England

# %%
regionregiontypes_df = pd.read_excel(filename, sheet_name='RegionRegionTypes')
regionregiontypes_df.head()
# Out:
#   RegionType        RegionName
# 0         UK                UK
# 1         GB                GB
# 2     Nation           England
# 3     Nation  Northern Ireland
# 4     Nation          Scotland

# %%
regionregiontypes_df.to_sql('RegionRegionTypes', conn, if_exists='append', index=False)
db_regionregiontypes_df = pd.read_sql('SELECT * From RegionRegionTypes',conn)
db_regionregiontypes_df.head()
# Out:
#      RegionXTypesID     RegionName RegionType
# 0              GBGB             GB         GB
# 1       ICMMidlands       Midlands        ICM
# 2  ICMNorth England  North England        ICM
# 3       ICMScotland       Scotland        ICM
# 4   ICMSouth+London   South+London        ICM

# %%
parties_df = pd.read_excel(filename, sheet_name='Parties')
parties_df.head()
# Out:
#   PartyAbbreviation              PartyFullName
# 0          Alliance                   Alliance
# 1               Con               Conservative
# 2               DUP  Democratic Unionist Party
# 3             Green                      Green
# 4               Lab                     Labour

# %%
parties_df.to_sql('Parties', conn, if_exists='append', index=False)
db_parties_df = pd.read_sql('SELECT * From Parties',conn)
db_parties_df.head()
# Out:
#   PartyAbbreviation              PartyFullName
# 0          Alliance                   Alliance
# 1               Con               Conservative
# 2               DUP  Democratic Unionist Party
# 3             Green                      Green
# 4               Lab                     Labour

# %%
pollsters_df = pd.read_excel(filename, sheet_name='Pollsters')
pollsters_df.head()
# Out:
#   PollsterName DefaultRegionType
# 0          BMG               NaN
# 1    Deltapoll         Survation
# 2   FindOutNow               NaN
# 3    Focaldata               NaN
# 4          ICM               ICM

# %%
pollsters_df.to_sql('Pollsters', conn, if_exists='append', index=False)
db_pollsters_df = pd.read_sql('SELECT * From Pollsters',conn)
db_pollsters_df.head()
# Out:
#   PollsterName DefaultRegionType
# 0          BMG              None
# 1    Deltapoll         Survation
# 2   FindOutNow              None
# 3    Focaldata              None
# 4          ICM               ICM

# %%
constituencies_df = pd.read_excel(filename, sheet_name='Constituencies')
constituencies_df.head()
# Out:
#        ONSID    ConstituencyName          County    Nation ConstituencyType  \
# 0  W07000049            Aberavon  West Glamorgan     Wales           County
# 1  W07000058           Aberconwy           Clwyd     Wales           County
# 2  S14000001      Aberdeen North        Scotland  Scotland          Borough
# 3  S14000002      Aberdeen South        Scotland  Scotland          Borough
# 4  S14000003  Airdrie and Shotts        Scotland  Scotland           County
#
#   ITL1Region   Latitude  Longitude FirstParty SecondParty PreviousFirstParty  \
# 0      Wales  51.588490   -3.70476        Lab         Con                Lab
# 1      Wales  53.130638   -3.85333        Con         Lab                Con
# 2   Scotland  57.171230   -2.17038        SNP         Con                SNP
# 3   Scotland  57.114052   -2.26363        SNP         Con                Con
# 4   Scotland  55.842899   -3.86475        SNP         Lab                SNP
#
#    Electorate  ValidVotes  InvalidVotes  MajorityVotes  MajorityShare  \
# 0       50750       31598            82          10490       0.331983
# 1       44699       31865           123           2034       0.063832
# 2       62489       37413            72          12670       0.338652
# 3       65719       45638           131           3990       0.087427
# 4       64011       39772            91           5201       0.130770
#
#   MPFirstName MPSurname MPGender     DeclarationTime
# 0     Stephen   Kinnock     Male 2019-12-13 02:30:00
# 1       Robin    Millar     Male 2019-12-13 03:09:00
# 2      Kirsty  Blackman   Female 2019-12-13 03:13:00
# 3     Stephen     Flynn     Male 2019-12-13 03:34:00
# 4        Neil      Gray     Male 2019-12-13 02:59:00

# %%
constituencies_df.to_sql('Constituencies', conn, if_exists='append', index=False)
db_constituencies_df = pd.read_sql('SELECT * From Constituencies',conn)
db_constituencies_df.head()
# Out:
#        ONSID    ConstituencyName          County    Nation ConstituencyType  \
# 0  W07000049            Aberavon  West Glamorgan     Wales           County
# 1  W07000058           Aberconwy           Clwyd     Wales           County
# 2  S14000001      Aberdeen North        Scotland  Scotland          Borough
# 3  S14000002      Aberdeen South        Scotland  Scotland          Borough
# 4  S14000003  Airdrie and Shotts        Scotland  Scotland           County
#
#   ITL1Region   Latitude  Longitude FirstParty SecondParty PreviousFirstParty  \
# 0      Wales  51.588490   -3.70476        Lab         Con                Lab
# 1      Wales  53.130638   -3.85333        Con         Lab                Con
# 2   Scotland  57.171230   -2.17038        SNP         Con                SNP
# 3   Scotland  57.114052   -2.26363        SNP         Con                Con
# 4   Scotland  55.842899   -3.86475        SNP         Lab                SNP
#
#    Electorate  ValidVotes  Invalidvotes  MajorityVotes  MajorityShare  \
# 0       50750       31598            82          10490       0.331983
# 1       44699       31865           123           2034       0.063832
# 2       62489       37413            72          12670       0.338652
# 3       65719       45638           131           3990       0.087427
# 4       64011       39772            91           5201       0.130770
#
#   MPFirstName MPSurname MPGender     DeclarationTime
# 0     Stephen   Kinnock     Male 2019-12-13 02:30:00
# 1       Robin    Millar     Male 2019-12-13 03:09:00
# 2      Kirsty  Blackman   Female 2019-12-13 03:13:00
# 3     Stephen     Flynn     Male 2019-12-13 03:34:00
# 4        Neil      Gray     Male 2019-12-13 02:59:00

# %%
RegionConstituencies_df = pd.read_excel(filename, sheet_name='RegionConstituencies')
RegionConstituencies_df.head()
# Out:
#          RegionName ConstituencyName
# 0                GB         Aberavon
# 1    Midlands+Wales         Aberavon
# 2  South West Wales         Aberavon
# 3                UK         Aberavon
# 4             Wales         Aberavon

# %%
RegionConstituencies_df.to_sql('RegionConstituencies', conn, if_exists='append', index=False)
db_RegionConstituencies_df = pd.read_sql('SELECT * From RegionConstituencies',conn)
db_RegionConstituencies_df.head()
# Out:
#                                         RegionConsID  \
# 0     Cardiff and South Central WalesCardiff Central
# 1       Cardiff and South Central WalesCardiff North
# 2  Cardiff and South Central WalesCardiff South a...
# 3        Cardiff and South Central WalesCardiff West
# 4        Cardiff and South Central WalesCynon Valley
#
#             ConstituencyName                       RegionName
# 0            Cardiff Central  Cardiff and South Central Wales
# 1              Cardiff North  Cardiff and South Central Wales
# 2  Cardiff South and Penarth  Cardiff and South Central Wales
# 3               Cardiff West  Cardiff and South Central Wales
# 4               Cynon Valley  Cardiff and South Central Wales

# %%
Candidates_df = pd.read_excel(filename, sheet_name='Candidates')
Candidates_df.head()
# Out:
#   Constituency   Party  FirstName         Surname  Gender  SittingMP  \
# 0     Aberavon     Lab    Stephen         Kinnock    Male          1
# 1     Aberavon     Con  Charlotte            Lang  Female          0
# 2     Aberavon  Reform     Glenda          Davies  Female          0
# 3     Aberavon      PC      Nigel            Hunt    Male          0
# 4     Aberavon      LD     Sheila  Kingston-Jones  Female          0
#
#    FormerMP  PreviousVotes  PreviousShare
# 0         1          17008       0.538262
# 1         0           6518       0.206279
# 2         0           3108       0.098361
# 3         0           2711       0.085797
# 4         0           1072       0.033926

# %%
Candidates_df.to_sql('Candidates', conn, if_exists='append', index=False)
db_Candidates_df = pd.read_sql('SELECT * From Candidates',conn)
db_Candidates_df.head()
# Out:
#      CandidateID Constituency  Party  SittingMP  FormerMP  FirstName  \
# 0    AberavonCon     Aberavon    Con      False     False  Charlotte
# 1  AberavonGreen     Aberavon  Green      False     False    Giorgia
# 2    AberavonLab     Aberavon    Lab       True      True    Stephen
# 3     AberavonLD     Aberavon     LD      False     False     Sheila
# 4  AberavonOther     Aberavon  Other      False     False    Captain
#
#           Surname  Gender  PreviousVotes  PreviousShare
# 0            Lang  Female           6518       0.206279
# 1          Finney  Female            450       0.014241
# 2         Kinnock    Male          17008       0.538262
# 3  Kingston-Jones  Female           1072       0.033926
# 4           Beany    Male            731       0.023134

# %%
conn.close()
